# %%
import pandas as pd

# %%
data = pd.read_excel("Bike_Sales (1).xlsx")
data
# Out:
#              Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0      2017-01-01    1   January  2017            17           Youth (<25)
# 1      2017-01-01    1   January  2017            23           Youth (<25)
# 2      2017-01-01    1   January  2017            33  Young Adults (25-34)
# 3      2017-01-01    1   January  2017            39        Adults (35-64)
# 4      2017-01-01    1   January  2017            42        Adults (35-64)
# ...           ...  ...       ...   ...           ...                   ...
# 113031 2021-12-31   31  December  2021            52        Adults (35-64)
# 113032 2021-12-31   31  December  2021            25  Young Adults (25-34)
# 113033 2021-12-31   31  December  2021            26  Young Adults (25-34)
# 113034 2021-12-31   31  December  2021            33  Young Adults (25-34)
# 113035 2021-12-31   31  December  2021            44        Adults (35-64)
#
# ...

# %%
data.describe()
# Out:
#                                 Date            Day           Year  \
# count                         113036  113036.000000  113036.000000
# mean   2020-01-06 01:36:09.376127744      15.665753    2019.520153
# min              2017-01-01 00:00:00       1.000000    2017.000000
# 25%              2019-01-09 00:00:00       8.000000    2019.000000
# 50%              2019-10-16 00:00:00      16.000000    2019.500000
# 75%              2021-01-28 00:00:00      23.000000    2021.000000
# max              2021-12-31 00:00:00      31.000000    2021.000000
# std                              NaN       8.781567       1.179704
#
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  113036.000000   113036.000000  113036.000000  113036.000000
# mean       35.919212       11.901660     267.296366     452.938427
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# ...

# %%
# %pip install datascrubber
# Out:
# ...
#   Using cached datascrubber-0.1.5-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# ...
#   Using cached scikit_learn-1.5.2-cp312-cp312-win_amd64.whl.metadata (13 kB)
# ...
#   Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.54.1-cp312-cp312-win_amd64.whl.metadata (167 kB)
# ...
#   Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...

# %%
# %pip install seaborn
# Out:
# ...
#
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #compairing two continuous variables

# %%
data.boxplot(column='Profit', by='Unit_Cost', figsize=(18,10))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='Unit_Cost'>

# %% [markdown]
# #graph showing a single categoricak variable

# %%
sns.boxplot(x=data['Unit_Cost'])
plt.title('Boxplot of Unit_Cost')
plt.xlabel('Profit')
plt.show()

# %% [markdown]
# #Graph showing a single categorical variable

# %%
#generating a barplot
sns.countplot(x='Age_Group', data = data)
plt.title('Distribution of Age Group')
plt.xlabel('Age_Group')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #comparing a two categorical variables

# %%
#generating a barplot
sns.countplot(x='Age_Group', hue='Year', data=data)
plt.title('Comparison of Age Group by year')
plt.xlabel('Year')
plt.ylabel('Age_Group')
plt.show()

# %% [markdown]
# #compairing one continuous variable and one categorical variable

# %%
#generating a boxplot 
sns.boxplot(x='Age_Group', y='Unit_Cost', data=data)
plt.title('Unit Cost by Age_Group')
plt.xlabel('Age_Group')
plt.ylabel('Unit_Cost')
plt.show()

# %% [markdown]
# #Generating statistical tests

# %% [markdown]
# statistical tests for two continuous variables using the Pearson Correlation coefficient

# %%
# %pip install scipy
# Out:
# ...
#   Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.5/44.5 MB 430.4 kB/s eta 0:01:43
#    ---------------------------------------- 0.5/44.5 MB 430.4 kB/s eta 0:01:43
#    ---------------------------------------- 0.5/44.5 MB 430.4 kB/s eta 0:01:43
#     --------------------------------------- 0.8/44.5 MB 404.5 kB/s eta 0:01:49
#     --------------------------------------- 0.8/44.5 MB 404.5 kB/s eta 0:01:49
# ...

# %%
import scipy.stats as stats

# %%
#pearson correlation test between unit cost and profit
corr, p_value = stats.pearsonr(data['Unit_Cost'], data['Profit'])

print(f'Pearson correlation coefficient: {corr}')
print(f'p-value: {p_value}')
# Out:
# Pearson correlation coefficient: 0.7883307282059594
# p-value: 0.0

# %% [markdown]
# Pearson correlation coefficient is  0.7883307282059594 which indicates a strong positive correlation between unit cost and profit
# p-value: 0.0

# %% [markdown]
# statistical test between two categorical variables

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
#creating a contingency table
contingency_table = pd.crosstab(data['Age_Group'], data['Year'])
print("Contingency Table:")
print(contingency_table)
# Out:
# Contingency Table:
# Year                  2017   2018   2019   2020   2021
# Age_Group
# Adults (35-64)        1207  11236  15469  11236  16676
# Seniors (64+)            7    131    227    131    234
# Young Adults (25-34)   974   8785   9568   8785  10542
# Youth (<25)            489   4291   4134   4291   4623

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# %%
#Performing the chi square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"\nChi-square Statistic: {chi2:.2f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:")
print(expected)
# Out:
# Chi-square Statistic: 546.34
# P-value: 0.0000
# Degrees of Freedom: 12
# Expected Frequencies:
# [[ 1322.06419194 12071.42885452 14518.50695354 12071.42885452
#   15840.57114548]
#  [   17.288386     157.85581585   189.85579815   157.85581585
#     207.14418415]
#  [  915.43188011  8358.57356948 10052.99455041  8358.57356948
#   10968.42643052]
#  [  422.21554195  3855.14176015  4636.6426979   3855.14176015
#    5058.85823985]]

# %%
alpha = 0.05  # significance level
if p < alpha:
    print("Reject the null hypothesis: There is a significant association between Age_Group and year.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between Age_Group and year.")
# Out:
# Reject the null hypothesis: There is a significant association between Age_Group and year.

# %%
#tests between one categorical and one continuous variable
import pandas as pd
from scipy.stats import f_oneway

# %%
groups = [data[data['Age_Group'] == group]['Profit'] for group in data['Age_Group'].unique()]

# %%
f_stat, p_value = f_oneway(*groups)
print(f"ANOVA F-Statistic: {f_stat:.2f}")
print(f"P-value: {p_value:.4f}")
# Out:
# ANOVA F-Statistic: 57.57
# P-value: 0.0000

# %% [markdown]
# ANOVA F-Statistic: 57.57
# P-value: 0.0000

# %%
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: At least one group mean is significantly different.")
else:
    print("Fail to reject the null hypothesis: All group means are not significantly different.")
# Out:
# Reject the null hypothesis: At least one group mean is significantly different.

# %% [markdown]
# Reject the null hypothesis: At least one group mean is significantly different.

# %% [markdown]
# KEMBABAZI ANITAH M24B38/007
